# %%
# %load_ext autoreload
# %autoreload 2

from src.utils.table_maintenance import optimize_and_vacuum_tables
optimize_and_vacuum_tables(spark)
print("Delta OPTIMIZE and VACUUM completed successfully")
