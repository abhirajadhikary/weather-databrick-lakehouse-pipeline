# %%
import sys
from src.transformations.silver_transformer import process_bronze_to_silver
process_bronze_to_silver(spark)
df_silver = spark.read.table("weather_catalog.silver.slv_weather_observations")
display(df_silver)
