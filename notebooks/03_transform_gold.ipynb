# %%
# %load_ext autoreload
# %autoreload 2
import sys
from src.transformations.gold_transformer import process_silver_to_gold

process_silver_to_gold(spark)

# Display Fact Table
display(spark.read.table("weather_catalog.gold.fact_weather_observations"))

# Display Daily Aggregated Metrics
display(spark.read.table("weather_catalog.gold.gld_daily_weather_metrics"))
